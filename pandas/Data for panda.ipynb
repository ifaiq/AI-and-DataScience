# %%
import pandas as pd
import numpy as np
from pandas import DataFrame, Series
from fuzzywuzzy import fuzz as f

# %% [markdown]
# #Add following line to replace Space in column name with Underscore
# #data.columns = [c.replace(' ', '_') for c in data.columns]

# %%
data = pd.read_csv('data_for_panda_exercise.csv')
data2 = pd.read_csv('Election_data_2018.csv')

# %%
data2.columns

# %%
data2.tail(10)
# Out:
#      District                Seat Constituency_title           Candidate_Name  \
# 3157  Lasbela  Lasbela-cum-Gwadar             NA-272                Attaullah
# 3158  Lasbela  Lasbela-cum-Gwadar             NA-272                Ali Ahmed
# 3159  Lasbela  Lasbela-cum-Gwadar             NA-272               Ali Baloch
# 3160  Lasbela  Lasbela-cum-Gwadar             NA-272            Ghulam Sarwar
# 3161  Lasbela  Lasbela-cum-Gwadar             NA-272     Ghulam Mustafa Malik
# 3162  Lasbela  Lasbela-cum-Gwadar             NA-272   Mohammad Akhtar Mengal
# 3163  Lasbela  Lasbela-cum-Gwadar             NA-272  Mohammad Aslam Bhootani
# 3164  Lasbela  Lasbela-cum-Gwadar             NA-272           Mohammad Akram
# 3165  Lasbela  Lasbela-cum-Gwadar             NA-272       Nawab Khan Buzenjo
# 3166  Lasbela  Lasbela-cum-Gwadar             NA-272      Wazir Ahmed Noorani
#
#                                    Party
# 3157  Balochistan National Party (Awami)
# ...

# %%
print(data.shape)
# Out:
# (48, 14)

# %%
data.head(10)
# Out:
#     Student_Code  Degree      Student_Name  Mid  Quiz_1  Quiz_2  \
# 0   022-14-19987  BS(CS)       Abdul Basit   28     8.0     3.0
# 1  022-14-110233  BS(CS)       Adeel Ahmed   17     NaN     5.0
# 2  022-14-110585  BS(CS)      Afrah Zareen   18     5.0     2.0
# 3   022-14-19718  BS(CS)    Ahmed Ali Raza   14     7.0     2.0
# 4  022-14-110648  BS(CS)   Ahsan Ali Vohra   27     7.0     6.0
# 5  022-14-110232  BS(CS)       Ameer Hamza   25     9.0     6.0
# 6  022-14-110588  BS(CS)     Anas Ali Khan   28     5.0     6.0
# 7  022-14-110388  BS(CS)  Aneebullah Niazi   26     9.0     6.0
# 8  022-14-110601  BS(CS)    Areesha Sohail   19     9.0     4.0
# 9  022-14-110599  BS(CS)           Arsalan   28     8.0     6.0
#
#    Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 0                8          7.0          9.0                    9
# 1                5          8.0         10.0                   10
# ...

# %%
print(data)
# Out:
#      Student_Code  Degree                    Student_Name  Mid  Quiz_1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
data.groupby(['Quiz_1']).count()
# Out:
#         Student_Code  Degree  Student_Name  Mid  Quiz_2  Best_of_Quizzes  \
# Quiz_1
# 4.0                2       2             2    2       2                2
# 5.0                7       7             7    7       6                7
# 6.0                3       3             3    3       2                3
# 7.0               10      10            10   10      10               10
# 8.0               10      10            10   10      10               10
# 9.0               13      13            13   13      13               13
#
#         Assignment1  Assignment2  Best_of_Assignments  Total Sessional (50)  \
# Quiz_1
# 4.0               2            2                    2                     2
# 5.0               7            7                    7                     7
# 6.0               3            3                    3                     3
# 7.0               9            6                   10                    10
# ...

# %%
data[(data.Best_of_Quizzes == 9) & (data.Grade =='A')]
# Out:
#      Student_Code  Degree       Student_Name  Mid  Quiz_1  Quiz_2  \
# 7   022-14-110388  BS(CS)   Aneebullah Niazi   26     9.0     6.0
# 19  022-14-110222  BS(CS)    Mohammad Hunain   27     9.0     6.0
# 25  022-14-110105  BS(CS)     Muhammad Faraz   26     9.0     6.0
# 34  022-14-110413  BS(CS)   Nazeer Bin Zafar   25     9.0     6.0
# 40  022-14-110584  BS(CS)        Sharif Taqi   27     9.0     6.0
# 45  022-14-110400  BS(CS)  Syeda Sabika Raza   27     9.0     6.0
#
#     Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 7                 9          8.0         10.0                   10
# 19                9          8.0         10.0                   10
# 25                9          8.0         10.0                   10
# 34                9          8.0         10.0                   10
# 40                9          8.0         10.0                   10
# 45                9          9.0          NaN                    9
#
# ...

# %%
data[(data.Student_Name.str.startswith('F'))& (data.Grade == 'A')]
# Out:
#      Student_Code  Degree         Student_Name  Mid  Quiz_1  Quiz_2  \
# 10  022-14-110214  BS(CS)  Fatima Haider Warsi   30     8.0     7.0
#
#     Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 10                8          8.0          NaN                    8
#
#     Total Sessional (50)  Final(50)  Total(100) Grade
# 10                    46       45.0          91     A

# %%
data[data.Mid>25]
# Out:
#      Student_Code  Degree             Student_Name  Mid  Quiz_1  Quiz_2  \
# 0    022-14-19987  BS(CS)              Abdul Basit   28     8.0     3.0
# 4   022-14-110648  BS(CS)          Ahsan Ali Vohra   27     7.0     6.0
# 6   022-14-110588  BS(CS)            Anas Ali Khan   28     5.0     6.0
# 7   022-14-110388  BS(CS)         Aneebullah Niazi   26     9.0     6.0
# 9   022-14-110599  BS(CS)                  Arsalan   28     8.0     6.0
# 10  022-14-110214  BS(CS)      Fatima Haider Warsi   30     8.0     7.0
# 11  022-14-110591  BS(CS)              Habib Ullah   28     8.0     5.0
# 19  022-14-110222  BS(CS)          Mohammad Hunain   27     9.0     6.0
# 23   022-14-19983  BS(CS)       Muhammad Ali Iqbal   26     5.0     NaN
# 24  022-14-110215  BS(CS)           Muhammad Bilal   28     5.0     4.0
# 25  022-14-110105  BS(CS)           Muhammad Faraz   26     9.0     6.0
# 26  022-14-110370  BS(CS)  Muhammad Ghazali Faridi   27     6.0     NaN
# ...

# %%
d1 = data.loc[:,"Student_Code":"Grade"]
d1
# Out:
#      Student_Code  Degree                    Student_Name  Mid  Quiz_1  \
# 0    022-14-19987  BS(CS)                     Abdul Basit   28     8.0
# 1   022-14-110233  BS(CS)                     Adeel Ahmed   17     NaN
# 2   022-14-110585  BS(CS)                    Afrah Zareen   18     5.0
# 3    022-14-19718  BS(CS)                  Ahmed Ali Raza   14     7.0
# 4   022-14-110648  BS(CS)                 Ahsan Ali Vohra   27     7.0
# 5   022-14-110232  BS(CS)                     Ameer Hamza   25     9.0
# 6   022-14-110588  BS(CS)                   Anas Ali Khan   28     5.0
# 7   022-14-110388  BS(CS)                Aneebullah Niazi   26     9.0
# 8   022-14-110601  BS(CS)                  Areesha Sohail   19     9.0
# 9   022-14-110599  BS(CS)                         Arsalan   28     8.0
# 10  022-14-110214  BS(CS)             Fatima Haider Warsi   30     8.0
# 11  022-14-110591  BS(CS)                     Habib Ullah   28     8.0
# ...

# %%
# null values delete hojaye gee

data = data.dropna()

# %%
data[['Student_Name','Mid','Grade']][(data.Grade=='A')]
# Out:
#         Student_Name  Mid Grade
# 7   Aneebullah Niazi   26     A
# 19   Mohammad Hunain   27     A
# 25    Muhammad Faraz   26     A
# 34  Nazeer Bin Zafar   25     A
# 40       Sharif Taqi   27     A

# %%
data[(data.Student_Name.str.contains('Ali'))]
# Out:
#     Student_Code  Degree     Student_Name  Mid  Quiz_1  Quiz_2  \
# 4  022-14-110648  BS(CS)  Ahsan Ali Vohra   27     7.0     6.0
# 6  022-14-110588  BS(CS)    Anas Ali Khan   28     5.0     6.0
#
#    Best_of_Quizzes  Assignment1  Assignment2  Best_of_Assignments  \
# 4                7          7.0          9.0                    9
# 6                6          8.0         10.0                   10
#
#    Total Sessional (50)  Final(50)  Total(100) Grade
# 4                    43       34.0          77     B
# 6                    44       30.0          74     B

# %%
data[(data.Student_Name.str.endswith('Ahmed'))]
# Out:
#      Student_Code  Degree  Student_Name  Mid  Quiz_1  Quiz_2  Best_of_Quizzes  \
# 16  022-14-110596  BS(CS)  Hassam Ahmed   23     5.0     5.0                5
# 47  022-14-110219  BS(CS)   Waqar Ahmed   11     9.0     5.0                9
#
#     Assignment1  Assignment2  Best_of_Assignments  Total Sessional (50)  \
# 16          7.0          9.0                    9                    37
# 47          5.0          7.0                    7                    27
#
#     Final(50)  Total(100) Grade
# 16       35.0          72     B
# 47       19.0          46     F

# %%
data[(data.Student_Name.str.startswith('Hassam '))&(data.Student_Name.str.endswith('Ahmed'))]
# Out:
#      Student_Code  Degree  Student_Name  Mid  Quiz_1  Quiz_2  Best_of_Quizzes  \
# 16  022-14-110596  BS(CS)  Hassam Ahmed   23     5.0     5.0                5
#
#     Assignment1  Assignment2  Best_of_Assignments  Total Sessional (50)  \
# 16          7.0          9.0                    9                    37
#
#     Final(50)  Total(100) Grade
# 16       35.0          72     B

# %%
person = pd.DataFrame({
    'name':['Faiq', 'Ahmed', 'Shariff', 'Taha', 'Fatima', 'Samia'],
    'age': np.random.randint(18,30, size =[6]), #[23,32,23,43,51,21]
    'percent': np.random.randint(1,100, size=[6])
})

person
# Out:
#       name  age  percent
# 0     Faiq   29       65
# 1    Ahmed   27       25
# 2  Shariff   28       99
# 3     Taha   20       26
# 4   Fatima   27       18
# 5    Samia   21       34

# %%
def fun(age):
    if age>20:
        return "Adult"
    else:
        return "Kid"

# %%
person['Status'] = person['age'].map(fun) # or we can use .apply(fun)
person
# Out:
#       name  age  percent Status
# 0     Faiq   29       65  Adult
# 1    Ahmed   27       25  Adult
# 2  Shariff   28       99  Adult
# 3     Taha   20       26    Kid
# 4   Fatima   27       18  Adult
# 5    Samia   21       34  Adult

# %%
elecdata = pd.read_csv("Election_data_2018.csv")
print(elecdata)
# Out:
#      District                     Seat Constituency_title  \
# 0     Chitral                  Chitral               NA-1
# 1     Chitral                  Chitral               NA-1
# 2     Chitral                  Chitral               NA-1
# 3     Chitral                  Chitral               NA-1
# 4     Chitral                  Chitral               NA-1
# 5     Chitral                  Chitral               NA-1
# 6     Chitral                  Chitral               NA-1
# 7     Chitral                  Chitral               NA-1
# 8     Chitral                  Chitral               NA-1
# 9     Chitral                  Chitral               NA-1
# 10    Chitral                  Chitral               NA-1
# 11       Swat                   Swat-I              NA-2
# 12       Swat                   Swat-I              NA-2
# 13       Swat                   Swat-I              NA-2
# 14       Swat                   Swat-I              NA-2
# ...

# %%
elecdata.columns
# Out:
# Index(['District', 'Seat', 'Constituency_title', 'Candidate_Name', 'Party'], dtype='object')

# %%
elecdata.groupby(['District']).count()
# Out:
#                            Seat  Constituency_title  Candidate_Name  Party
# District
# Abbottabad-1                 13                  13              13     13
# Abbottabad-2                 18                  18              18     18
# Attock                        8                   8               8      8
# Badin                        14                  14              14     14
# Bahawalnagar                 41                  41              41     41
# Bahawalpur                   41                  41              41     41
# Bannu                        12                  12              12     12
# Battagram                     8                   8               8      8
# Bhakkar                      19                  19              19     19
# Buner                         7                   7               7      7
# Chagai                       18                  18              18     18
# ...

# %%
elecdata.groupby('Candidate_Name')['Party'].count().nlargest(6)
# Out:
# Candidate_Name
# Muhammad Anwar     6
# Muhammad Ramzan    5
# Abdul Wahab        4
# Farooq Shah        4
# Muhammad Aslam     4
# Muhammad Islam     4
# Name: Party, dtype: int64

# %%
elecdata[(elecdata.Party == 'Pakistan Tehreek-e-Insaf')&(elecdata.Candidate_Name == 'Imran Ahmed Khan Niazi')]
# Out:
#       District             Seat Constituency_title          Candidate_Name  \
# 2667  Karachi   Karachi East-II             NA-243  Imran Ahmed Khan Niazi
#
#                          Party
# 2667  Pakistan Tehreek-e-Insaf

# %%
#Covariance and variance
#APIs
