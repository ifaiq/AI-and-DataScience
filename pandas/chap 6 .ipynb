# 12531   622024458  4036707   1/4/2017 10:02:43 AM       1190            905
# 12532   622024126  4036707   1/4/2017 10:02:19 AM       1190          41113
# 12533   622023818  4036707   1/4/2017 10:01:57 AM       1190          30171
# 12534   622023817  4036707   1/4/2017 10:01:57 AM       1190          40845
# 12535   622023789  4036707   1/4/2017 10:01:54 AM       1190          10171
# 12536   622023544  4036707   1/4/2017 10:01:30 AM       1190          40900
# 12537   622023411  4036707   1/4/2017 10:01:13 AM       1190          30014
# 12538   622023370  4036707   1/4/2017 10:01:08 AM       1190          41543
# 12539   622023359  4036707   1/4/2017 10:01:07 AM       1190           1545
# 12540   622023361  4036707   1/4/2017 10:01:07 AM       1190          49024
# 12541   622022979  4036707   1/4/2017 10:00:47 AM       1190          41541
#
#                                              DESCRIPTION
# 0           Mobile App: Token Verified At Login: Success
# 1                       Mobile:Transactions List Success
# 2                         DisplayGetLastDrCrTransHistory
# 3                                            RefreshAcct
# 4           Mobile App: Token Verified At Login: Success
# 5                       Mobile:Transactions List Success
# 6                                            GetBillData
# 7           Mobile App: Token Verified At Login: Success
# 8                       Mobile:Transactions List Success
# 9                                            GetBillData
# 10          Mobile App: Token Verified At Login: Success
# 11                                    GetMobileBillsData
# 12                                           GetBillData
# 13                                           GetBillData
# 14                                           GetBillData
# 15                      Mobile:Transactions List Success
# 16          Mobile App: Token Verified At Login: Success
# 17                      Mobile:Transactions List Success
# 18                      Mobile:Transactions List Success
# 19                      Mobile:Transactions List Success
# 20                              Bill Payment: Successful
# 21                    Mobile Transaction Source inserted
# 22          Mobile App: Token Verified At Login: Success
# 23            Mobile App: Duplicate Transaction Attempts
# 24                               payAllBillConfirmSubmit
# 25            Mobile App: Duplicate Transaction Attempts
# 26          Mobile App: Token Verified At Login: Success
# 27                                    PayBillSubmitClick
# 28                                             getLimits
# 29                                    GetMobileTopUpData
# ...                                                  ...
# 12512                   Mobile:Transactions List Success
# 12513                   Mobile:Transactions List Success
# 12514                   Mobile:Transactions List Success
# 12515         Mobile App: View Prepaid Service: Page Hit
# 12516                        Mobile App: TopUp: Page Hit
# 12517                   Mobile:Transactions List Success
# 12518                   Mobile:Transactions List Success
# 12519         Mobile App: View Prepaid Service: Page Hit
# 12520                   Mobile:Transactions List Success
# 12521              Mobile App: Login validation: Success
# 12522         Mobile:Login : Password Validation Success
# 12523           Mobile App: Password validation: Success
# 12524                             Website logon: Success
# 12525     Generate Email Successful: On Successful Login
# 12526              Mobile App: Login validation: Success
# 12527           Mobile App: Password validation: Failure
# 12528              Mobile App: Login validation: Success
# 12529                   Mobile:Transactions List Success
# 12530  Mobile App: Post: Viewed Account Statement - S...
# 12531           Post: Viewed Account Statement - Success
# 12532           Mobile App: Add Payee Account - Page Hit
# 12533                   Mobile:Transactions List Success
# 12534           Mobile App: E-Transactions List Page Hit
# 12535                   Mobile:Transactions List Success
# 12536                  Mobile App: My Accounts: Page Hit
# 12537         Mobile:Login : Password Validation Success
# 12538           Mobile App: Password validation: Success
# 12539                             Website logon: Success
# 12540     Generate Email Successful: On Successful Login
# 12541              Mobile App: Login validation: Success
#
# [12542 rows x 6 columns]

# %%
query = """
CREATE TABLE test
(a VARCHAR(20), b VARCHAR(20),
c REAL, d INTEGER
 );"""
sq = sqlite3.connect('mydata.sqlite')

# %%
sq

# %%
sq.commit()

# %%
data = [('Atlanta', 'Georgia', 1.25, 6),
         ('Tallahassee', 'Florida', 2.6, 3),
         ('Sacramento', 'California', 1.7, 5)]

# %%
stmt = "INSERT INTO test VALUES(?, ?, ?, ?)"

# %%
s.commit()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-24-6f9bb3ec4e4e> in <module>()
# ----> 1 s.commit()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4371                 return self[name]
# -> 4372             return object.__getattribute__(self, name)
#    4373
#    4374     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'commit'
